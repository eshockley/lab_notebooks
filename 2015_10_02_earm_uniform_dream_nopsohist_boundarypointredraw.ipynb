# %%
import pickle
from helper_fxns import convert_param_vec_dict_to_param_dict, gelman_rubin_trace_dict, print_convergence_summary, sample_plots, create_trace_matrix, plot_histograms
from earm.lopez_embedded import model
# %matplotlib inline
# Out:
# Warning: statsmodels and/or patsy not found, not importing glm submodule.
# /Library/Python/2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# /Library/Python/2.7/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
trace = pickle.load(open('/Users/Erin/git/moo_and_mcmc/pymc/earm_mtdreamzs_5chain_nopsohist_pointredraw.p'))

# %%
trace_momp = trace['momp']
trace_ecrp = trace['ecrp']
trace_icrp = trace['icrp']

# %%
del trace['momp']
del trace['ecrp']
del trace['icrp']

# %%
import numpy as np

# %%
param_trace = convert_param_vec_dict_to_param_dict(trace, model.parameters_rules())

# %%
del param_trace['param_list']

# %%
gelman_rubin_trace_dict(param_trace)
# Out:
# var:  catalyze_ApopC3pro_to_Apop_C3A_kc
# between chain variance:  5092.10398907
# within chain variance:  0.878622324864
# marginal posterior variance estimate:  1.38774486154
# var:  bind_C3A_C6pro_to_C3AC6pro_kf
# between chain variance:  1441.66090243
# within chain variance:  0.960049548578
# marginal posterior variance estimate:  1.10411963387
# var:  pore_transport_complex_BakA_4_SmacM_kr
# between chain variance:  34351.4216189
# within chain variance:  4.69915714877
# marginal posterior variance estimate:  8.13382939495
# var:  bind_C3A_C6pro_to_C3AC6pro_kr
# between chain variance:  159800.307606
# within chain variance:  13.3461880754
# marginal posterior variance estimate:  29.3248842172
# var:  catalyze_C8AC3pro_to_C8A_C3A_kc
# between chain variance:  1188.20977203
# within chain variance:  0.23053302867
# marginal posterior variance estimate:  0.349330952569
# var:  pore_transport_complex_BakA_4_SmacM_kf
# between chain variance:  24002.5991199
# within chain variance:  2.36496044874
# marginal posterior variance estimate:  4.76498386469
# var:  bind_BaxA_Bcl2_kr
# between chain variance:  73873.3888846
# within chain variance:  7.49901416405
# marginal posterior variance estimate:  14.8856031511
# var:  bind_C3A_PARPU_to_C3APARPU_kf
# between chain variance:  720.447897312
# within chain variance:  0.0381402330949
# marginal posterior variance estimate:  0.110181208803
# var:  bind_BidM_BclxLM_kr
# between chain variance:  46690.3002671
# within chain variance:  7.12182539953
# marginal posterior variance estimate:  11.7901432437
# var:  assemble_pore_sequential_Bax_2_kr
# between chain variance:  117386.076702
# within chain variance:  8.70201429929
# marginal posterior variance estimate:  20.439751768
# var:  pore_transport_complex_BaxA_4_CytoCM_kr
# between chain variance:  32404.0578417
# within chain variance:  4.68812085837
# marginal posterior variance estimate:  7.92805783046
# var:  bind_BAR_C8A_kf
# between chain variance:  9507.61947041
# within chain variance:  0.828528866228
# marginal posterior variance estimate:  1.77920796038
# var:  pore_transport_dissociate_BakA_4_SmacC_kc
# between chain variance:  7008.34254933
# within chain variance:  0.455159995903
# marginal posterior variance estimate:  1.15594873484
# var:  bind_BaxA_Bcl2_kf
# between chain variance:  64029.6022554
# within chain variance:  3.96227842219
# marginal posterior variance estimate:  10.3648424199
# var:  bind_BidM_BclxLM_kf
# between chain variance:  9190.27846298
# within chain variance:  3.21385844953
# marginal posterior variance estimate:  4.13256490998
# var:  assemble_pore_sequential_Bax_2_kf
# between chain variance:  40138.0356308
# within chain variance:  3.51765247577
# marginal posterior variance estimate:  7.5311042736
# var:  pore_transport_complex_BaxA_4_CytoCM_kf
# between chain variance:  41705.5170913
# within chain variance:  1.58072185229
# marginal posterior variance estimate:  5.75111548924
# var:  bind_BAR_C8A_kr
# between chain variance:  45402.0942812
# within chain variance:  8.64785614186
# marginal posterior variance estimate:  13.1872007844
# var:  bind_C3A_PARPU_to_C3APARPU_kr
# between chain variance:  22296.024537
# within chain variance:  1.54972652474
# marginal posterior variance estimate:  3.77917400579
# var:  bind_Apop_XIAP_kr
# between chain variance:  129466.378522
# within chain variance:  4.4794449682
# marginal posterior variance estimate:  17.4256348759
# var:  catalyze_BakABakM_to_BakA_BakA_kc
# between chain variance:  37676.296391
# within chain variance:  5.11600519659
# marginal posterior variance estimate:  8.88312323517
# var:  bind_BakA_BakM_to_BakABakM_kf
# between chain variance:  27163.4980149
# within chain variance:  2.32650159063
# marginal posterior variance estimate:  5.04261874196
# var:  convert_LR_to_DISC_kc
# between chain variance:  4.51891565537
# within chain variance:  0.00034758275812
# marginal posterior variance estimate:  0.00079943956538
# var:  bind_Apop_XIAP_kf
# between chain variance:  14727.7196131
# within chain variance:  4.70083757811
# marginal posterior variance estimate:  6.17313945565
# var:  pore_transport_dissociate_BaxA_4_SmacC_kc
# between chain variance:  8389.45191435
# within chain variance:  1.07973234815
# marginal posterior variance estimate:  1.91856956635
# var:  catalyze_C6AC8pro_to_C6A_C8A_kc
# between chain variance:  3245.26807417
# within chain variance:  0.318477543744
# marginal posterior variance estimate:  0.642972503406
# var:  bind_BakA_BakM_to_BakABakM_kr
# between chain variance:  21964.8814396
# within chain variance:  2.38497066364
# marginal posterior variance estimate:  4.58122031053
# var:  bind_BakA_Mcl1M_kf
# between chain variance:  11908.4932669
# within chain variance:  2.62396372194
# marginal posterior variance estimate:  3.81455065226
# var:  bind_C8A_BidU_to_C8ABidU_kf
# between chain variance:  616.267297177
# within chain variance:  0.0539699414286
# marginal posterior variance estimate:  0.115591274152
# var:  assemble_pore_sequential_Bax_4_kf
# between chain variance:  35108.9808279
# within chain variance:  2.10876100501
# marginal posterior variance estimate:  5.61944821169
# var:  bind_BakA_Mcl1M_kr
# between chain variance:  23423.8355008
# within chain variance:  2.36360263235
# marginal posterior variance estimate:  4.70574982217
# var:  assemble_pore_sequential_Bax_4_kr
# between chain variance:  52670.0457269
# within chain variance:  2.51115051643
# marginal posterior variance estimate:  7.77790397407
# var:  bind_C8A_BidU_to_C8ABidU_kr
# between chain variance:  211.501392209
# within chain variance:  0.028099303935
# marginal posterior variance estimate:  0.0492466332255
# var:  bind_XIAP_C3A_to_XIAPC3A_kr
# between chain variance:  272.037084647
# within chain variance:  0.0334851056391
# marginal posterior variance estimate:  0.0606854655932
# var:  bind_BidM_BaxC_to_BidMBaxC_kf
# between chain variance:  4892.47224651
# within chain variance:  0.840071456284
# marginal posterior variance estimate:  1.32923467379
# var:  bind_CytoCA_ApafI_to_CytoCAApafI_kr
# between chain variance:  24352.4225327
# within chain variance:  1.78516175885
# marginal posterior variance estimate:  4.22022549595
# var:  bind_BidM_BaxM_to_BidMBaxM_kr
# between chain variance:  24755.5930788
# within chain variance:  5.06675997705
# marginal posterior variance estimate:  7.54181260894
# var:  bind_BidM_BaxC_to_BidMBaxC_kr
# between chain variance:  30619.1600848
# within chain variance:  3.29220651547
# marginal posterior variance estimate:  6.35379330329
# var:  bind_CytoCA_ApafI_to_CytoCAApafI_kf
# between chain variance:  31549.135576
# within chain variance:  2.53264558867
# marginal posterior variance estimate:  5.68730588171
# var:  bind_XIAP_C3A_to_XIAPC3A_kf
# between chain variance:  225.317894584
# within chain variance:  0.469653801557
# marginal posterior variance estimate:  0.492138625635
# var:  catalyze_DISCC8pro_to_DISC_C8A_kc
# between chain variance:  13.84108274
# within chain variance:  0.00194375329389
# marginal posterior variance estimate:  0.00332766719256
# var:  pore_transport_dissociate_BaxA_4_CytoCC_kc
# between chain variance:  9507.88744629
# within chain variance:  0.813496815047
# marginal posterior variance estimate:  1.76420420999
# var:  bind_BidM_BaxM_to_BidMBaxM_kf
# between chain variance:  7083.20239787
# within chain variance:  1.59591432259
# marginal posterior variance estimate:  2.30407497094
# var:  assemble_pore_sequential_Bak_2_kr
# between chain variance:  55456.9367652
# within chain variance:  9.49749451674
# marginal posterior variance estimate:  15.0422384438
# var:  assemble_pore_sequential_Bak_3_kr
# between chain variance:  19938.240467
# within chain variance:  4.24893935141
# marginal posterior variance estimate:  6.24233850417
# var:  bind_DISC_flip_kr
# between chain variance:  1799.93523165
# within chain variance:  0.433968738733
# marginal posterior variance estimate:  0.613918865024
# var:  catalyze_C3AC6pro_to_C3A_C6A_kc
# between chain variance:  276.704952555
# within chain variance:  0.046235705221
# marginal posterior variance estimate:  0.073901576906
# var:  bind_DISC_flip_kf
# between chain variance:  13753.257859
# within chain variance:  1.14642374743
# marginal posterior variance estimate:  2.52163489096
# var:  assemble_pore_sequential_Bak_3_kf
# between chain variance:  25591.3525426
# within chain variance:  7.40987454682
# marginal posterior variance estimate:  9.96826881362
# var:  bind_NoxaM_Mcl1M_kf
# between chain variance:  17737.9722124
# within chain variance:  4.21279311587
# marginal posterior variance estimate:  5.9861690578
# var:  bind_NoxaM_Mcl1M_kr
# between chain variance:  84237.2744695
# within chain variance:  3.31108268653
# marginal posterior variance estimate:  11.7344790252
# var:  catalyze_BidMBaxC_to_BidM_BaxM_kc
# between chain variance:  3269.49082774
# within chain variance:  0.243940586668
# marginal posterior variance estimate:  0.570865275384
# var:  catalyze_XIAPC3A_to_XIAP_C3ub_kc
# between chain variance:  126.77610879
# within chain variance:  0.0607822931724
# marginal posterior variance estimate:  0.0734538258221
# var:  catalyze_C3APARPU_to_C3A_PARPC_kc
# between chain variance:  446.509982135
# within chain variance:  0.0443975751003
# marginal posterior variance estimate:  0.0890441335563
# var:  bind_Apop_C3pro_to_ApopC3pro_kf
# between chain variance:  37302.1421638
# within chain variance:  2.04700899148
# marginal posterior variance estimate:  5.77701850696
# var:  catalyze_CytoCAApafI_to_CytoCA_ApafA_kc
# between chain variance:  1875.96879558
# within chain variance:  1.12744163855
# marginal posterior variance estimate:  1.31492577394
# var:  bind_Apop_C3pro_to_ApopC3pro_kr
# between chain variance:  9995.01573835
# within chain variance:  3.78595439225
# marginal posterior variance estimate:  4.78507737065
# var:  bind_BadM_BclxLM_kf
# between chain variance:  41655.6322684
# within chain variance:  4.04438693047
# marginal posterior variance estimate:  8.20954571862
# var:  assemble_pore_sequential_Bak_2_kf
# between chain variance:  43618.6399951
# within chain variance:  3.76144252484
# marginal posterior variance estimate:  8.1229303801
# var:  assemble_pore_sequential_Bak_4_kf
# between chain variance:  11556.7928057
# within chain variance:  4.08836960522
# marginal posterior variance estimate:  5.24364004883
# var:  bind_BidM_BakM_to_BidMBakM_kr
# between chain variance:  20393.7519054
# within chain variance:  2.36521410267
# marginal posterior variance estimate:  4.4043527718
# var:  catalyze_C8ABidU_to_C8A_BidT_kc
# between chain variance:  6.8251073589
# within chain variance:  0.00176690514493
# marginal posterior variance estimate:  0.00244923919031
# var:  bind_BadM_BclxLM_kr
# between chain variance:  25242.3541735
# within chain variance:  11.5005611425
# marginal posterior variance estimate:  14.0236465038
# var:  assemble_pore_sequential_Bak_4_kr
# between chain variance:  57003.9785476
# within chain variance:  3.08906300674
# marginal posterior variance estimate:  8.78915195519
# var:  bind_SmacA_XIAP_kf
# between chain variance:  13569.5074312
# within chain variance:  1.5191465849
# marginal posterior variance estimate:  2.87594541336
# var:  pore_transport_complex_BaxA_4_SmacM_kr
# between chain variance:  100624.179891
# within chain variance:  5.62094003194
# marginal posterior variance estimate:  15.6827959271
# var:  convert_ApafA_C9_to_Apop_kf
# between chain variance:  3842.88901066
# within chain variance:  0.542963572467
# marginal posterior variance estimate:  0.927198177175
# var:  bind_BaxA_BclxLM_kr
# between chain variance:  66899.3718821
# within chain variance:  3.60590559606
# marginal posterior variance estimate:  10.2954821937
# var:  bind_BadM_Bcl2_kf
# between chain variance:  7691.49189914
# within chain variance:  1.35996993434
# marginal posterior variance estimate:  2.12898312726
# var:  bind_SmacA_XIAP_kr
# between chain variance:  118512.016979
# within chain variance:  13.4135860106
# marginal posterior variance estimate:  25.2634463499
# var:  bind_BaxA_BaxM_to_BaxABaxM_kr
# between chain variance:  6711.15185196
# within chain variance:  1.39250316304
# marginal posterior variance estimate:  2.06347909792
# var:  bind_BaxA_BclxLM_kf
# between chain variance:  9931.5746378
# within chain variance:  2.02651785565
# marginal posterior variance estimate:  3.01947266765
# var:  bind_BadM_Bcl2_kr
# between chain variance:  84628.0603218
# within chain variance:  5.37199650829
# marginal posterior variance estimate:  13.8342653408
# var:  pore_transport_complex_BaxA_4_SmacM_kf
# between chain variance:  23242.4843534
# within chain variance:  2.67334849602
# marginal posterior variance estimate:  4.99732959651
# var:  convert_ApafA_C9_to_Apop_kr
# between chain variance:  48715.3503024
# within chain variance:  5.17930571081
# marginal posterior variance estimate:  10.0503228105
# var:  bind_L_R_to_LR_kr
# between chain variance:  1293.63228223
# within chain variance:  0.210271074555
# marginal posterior variance estimate:  0.33961327567
# var:  catalyze_BidMBaxM_to_BidM_BaxA_kc
# between chain variance:  23335.874971
# within chain variance:  1.27062634767
# marginal posterior variance estimate:  3.60408678213
# var:  equilibrate_CytoCC_to_CytoCA_kr
# between chain variance:  6855.94139363
# within chain variance:  1.47715789149
# marginal posterior variance estimate:  2.16260431507
# var:  bind_BaxA_BaxM_to_BaxABaxM_kf
# between chain variance:  18807.526849
# within chain variance:  2.90623147742
# marginal posterior variance estimate:  4.78669353918
# var:  bind_L_R_to_LR_kf
# between chain variance:  24.9169191052
# within chain variance:  0.00622388408416
# marginal posterior variance estimate:  0.00871495360627
# var:  catalyze_BidMBakM_to_BidM_BakA_kc
# between chain variance:  7199.25246332
# within chain variance:  0.78008384498
# marginal posterior variance estimate:  1.49993108293
# var:  bind_BidM_BakM_to_BidMBakM_kf
# between chain variance:  39295.3350661
# within chain variance:  2.44922762778
# marginal posterior variance estimate:  6.37851621162
# var:  pore_transport_dissociate_BakA_4_CytoCC_kc
# between chain variance:  15788.3688998
# within chain variance:  0.671765472106
# marginal posterior variance estimate:  2.25053518554
# var:  equilibrate_CytoCC_to_CytoCA_kf
# between chain variance:  5020.96882585
# within chain variance:  0.551514135731
# marginal posterior variance estimate:  1.0535558669
# var:  bind_BidM_Bcl2M_kf
# between chain variance:  5799.24328541
# within chain variance:  1.35188117447
# marginal posterior variance estimate:  1.93167031489
# var:  equilibrate_SmacC_to_SmacA_kf
# between chain variance:  23777.9492139
# within chain variance:  2.05095003253
# marginal posterior variance estimate:  4.42853985892
# var:  bind_BidM_Bcl2M_kr
# between chain variance:  94277.4755319
# within chain variance:  7.3690395577
# marginal posterior variance estimate:  16.7960502069
# var:  equilibrate_SmacC_to_SmacA_kr
# between chain variance:  7816.28469951
# within chain variance:  1.61772040543
# marginal posterior variance estimate:  2.39918710334
# var:  bind_BidM_Mcl1M_kr
# between chain variance:  112224.676969
# within chain variance:  6.11693988928
# marginal posterior variance estimate:  17.3387958922
# var:  bind_C6A_C8pro_to_C6AC8pro_kf
# between chain variance:  6510.08795644
# within chain variance:  0.879574575736
# marginal posterior variance estimate:  1.53049541392
# var:  bind_BidM_Mcl1M_kf
# between chain variance:  5582.62033954
# within chain variance:  1.74091225549
# marginal posterior variance estimate:  2.29900019822
# var:  bind_C6A_C8pro_to_C6AC8pro_kr
# between chain variance:  13708.3098324
# within chain variance:  1.01552784389
# marginal posterior variance estimate:  2.38625727435
# var:  bind_BakA_BclxLM_kf
# between chain variance:  47585.9025501
# within chain variance:  5.89869662145
# marginal posterior variance estimate:  10.6566970068
# var:  equilibrate_BidT_to_BidM_kr
# between chain variance:  253.958513096
# within chain variance:  0.0392366979135
# marginal posterior variance estimate:  0.0646286255533
# var:  pore_transport_complex_BakA_4_CytoCM_kf
# between chain variance:  5831.54940189
# within chain variance:  1.19536789442
# marginal posterior variance estimate:  1.77840329782
# var:  bind_C8A_C3pro_to_C8AC3pro_kf
# between chain variance:  114.658032285
# within chain variance:  0.0123212865887
# marginal posterior variance estimate:  0.0237858576885
# var:  equilibrate_BidT_to_BidM_kf
# between chain variance:  4.34955418719
# within chain variance:  0.00426158183115
# marginal posterior variance estimate:  0.00469611109169
# var:  bind_BakA_BclxLM_kr
# between chain variance:  18179.971277
# within chain variance:  3.25053638641
# marginal posterior variance estimate:  5.06820846047
# var:  bind_C8A_C3pro_to_C8AC3pro_kr
# between chain variance:  4220.30226607
# within chain variance:  1.2165910613
# marginal posterior variance estimate:  1.6384996288
# var:  pore_transport_complex_BakA_4_CytoCM_kr
# between chain variance:  33028.4880134
# within chain variance:  4.51231665057
# marginal posterior variance estimate:  7.81471422024
# var:  catalyze_BaxABaxM_to_BaxA_BaxA_kc
# between chain variance:  1603.36077925
# within chain variance:  0.431476554271
# marginal posterior variance estimate:  0.591769484541
# var:  bind_DISC_C8pro_to_DISCC8pro_kf
# between chain variance:  2342.18265316
# within chain variance:  0.290113126832
# marginal posterior variance estimate:  0.524302380836
# var:  assemble_pore_sequential_Bax_3_kr
# between chain variance:  17111.2163554
# within chain variance:  2.27691890967
# marginal posterior variance estimate:  3.98781285332
# var:  bind_DISC_C8pro_to_DISCC8pro_kr
# between chain variance:  14558.8955865
# within chain variance:  0.521291095273
# marginal posterior variance estimate:  1.97712852482
# var:  assemble_pore_sequential_Bax_3_kf
# between chain variance:  39546.9048905
# within chain variance:  2.58892265326
# marginal posterior variance estimate:  6.54335425005
# {'assemble_pore_sequential_Bak_2_kf': 1.4695323481033618,
#  'assemble_pore_sequential_Bak_2_kr': 1.2584956205649196,
#  'assemble_pore_sequential_Bak_3_kf': 1.1598569867282829,
#  'assemble_pore_sequential_Bak_3_kr': 1.2120858791513272,
#  'assemble_pore_sequential_Bak_4_kf': 1.1325082135832598,
#  'assemble_pore_sequential_Bak_4_kr': 1.6867864483379778,
#  'assemble_pore_sequential_Bax_2_kf': 1.4631972110839908,
#  'assemble_pore_sequential_Bax_2_kr': 1.5325967924371022,
#  'assemble_pore_sequential_Bax_3_kf': 1.5897933600258201,
#  'assemble_pore_sequential_Bax_3_kr': 1.3234075332761379,
#  'assemble_pore_sequential_Bax_4_kf': 1.6324246930232733,
#  'assemble_pore_sequential_Bax_4_kr': 1.7599280619252451,
#  'bind_Apop_C3pro_to_ApopC3pro_kf': 1.6799331661735066,
#  'bind_Apop_C3pro_to_ApopC3pro_kr': 1.1242342013388651,
#  'bind_Apop_XIAP_kf': 1.1459493461165955,
#  'bind_Apop_XIAP_kr': 1.9723419060743701,
#  'bind_BAR_C8A_kf': 1.4654112945264854,
#  'bind_BAR_C8A_kr': 1.2348723916524722,
#  'bind_BadM_Bcl2_kf': 1.2511847896706954,
#  'bind_BadM_Bcl2_kr': 1.6047603661065393,
#  'bind_BadM_BclxLM_kf': 1.4247321145562983,
#  'bind_BadM_BclxLM_kr': 1.1042590375563606,
#  'bind_BakA_BakM_to_BakABakM_kf': 1.472232463481681,
#  'bind_BakA_BakM_to_BakABakM_kr': 1.3859548036552936,
#  'bind_BakA_BclxLM_kf': 1.3441052543513594,
#  'bind_BakA_BclxLM_kr': 1.2486758686859611,
#  'bind_BakA_Mcl1M_kf': 1.2057097695519501,
#  'bind_BakA_Mcl1M_kr': 1.4110005555795242,
#  'bind_BaxA_BaxM_to_BaxABaxM_kf': 1.2833724452663735,
#  'bind_BaxA_BaxM_to_BaxABaxM_kr': 1.2173121082761136,
#  'bind_BaxA_Bcl2_kf': 1.6173680407874951,
#  'bind_BaxA_Bcl2_kr': 1.4089031215028485,
#  'bind_BaxA_BclxLM_kf': 1.2206476912352422,
#  'bind_BaxA_BclxLM_kr': 1.6897255446718518,
#  'bind_BidM_BakM_to_BidMBakM_kf': 1.6137834488279976,
#  'bind_BidM_BakM_to_BidMBakM_kr': 1.3646014191343139,
#  'bind_BidM_BaxC_to_BidMBaxC_kf': 1.2578901503040181,
#  'bind_BidM_BaxC_to_BidMBaxC_kr': 1.3892263311466095,
#  'bind_BidM_BaxM_to_BidMBaxM_kf': 1.2015546180606356,
#  'bind_BidM_BaxM_to_BidMBaxM_kr': 1.2200361608255799,
#  'bind_BidM_Bcl2M_kf': 1.1953559365128283,
#  'bind_BidM_Bcl2M_kr': 1.509726013079997,
#  'bind_BidM_BclxLM_kf': 1.1339566948790549,
#  'bind_BidM_BclxLM_kr': 1.2866602369179174,
#  'bind_BidM_Mcl1M_kf': 1.1491614881678813,
#  'bind_BidM_Mcl1M_kr': 1.6836133498898522,
#  'bind_C3A_C6pro_to_C3AC6pro_kf': 1.0724109567579971,
#  'bind_C3A_C6pro_to_C3AC6pro_kr': 1.4823116869018613,
#  'bind_C3A_PARPU_to_C3APARPU_kf': 1.6996601608849611,
#  'bind_C3A_PARPU_to_C3APARPU_kr': 1.5616039943421614,
#  'bind_C6A_C8pro_to_C6AC8pro_kf': 1.3191059598807531,
#  'bind_C6A_C8pro_to_C6AC8pro_kr': 1.5328960846409594,
#  'bind_C8A_BidU_to_C8ABidU_kf': 1.4634791925476403,
#  'bind_C8A_BidU_to_C8ABidU_kr': 1.3238552181315213,
#  'bind_C8A_C3pro_to_C8AC3pro_kf': 1.389413065413992,
#  'bind_C8A_C3pro_to_C8AC3pro_kr': 1.1605152801407079,
#  'bind_CytoCA_ApafI_to_CytoCAApafI_kf': 1.49853221348683,
#  'bind_CytoCA_ApafI_to_CytoCAApafI_kr': 1.5375492684014014,
#  'bind_DISC_C8pro_to_DISCC8pro_kf': 1.3443341309684511,
#  'bind_DISC_C8pro_to_DISCC8pro_kr': 1.9474992440769183,
#  'bind_DISC_flip_kf': 1.4830934460339371,
#  'bind_DISC_flip_kr': 1.1893954328571674,
#  'bind_L_R_to_LR_kf': 1.1833188749777637,
#  'bind_L_R_to_LR_kr': 1.2708741974446929,
#  'bind_NoxaM_Mcl1M_kf': 1.1920361409647235,
#  'bind_NoxaM_Mcl1M_kr': 1.882551619276857,
#  'bind_SmacA_XIAP_kf': 1.3759114302257311,
#  'bind_SmacA_XIAP_kr': 1.3723783189745369,
#  'bind_XIAP_C3A_to_XIAPC3A_kf': 1.023657811881288,
#  'bind_XIAP_C3A_to_XIAPC3A_kr': 1.3462214541967925,
#  'catalyze_ApopC3pro_to_Apop_C3A_kc': 1.2567638990075216,
#  'catalyze_BakABakM_to_BakA_BakA_kc': 1.3177024550298331,
#  'catalyze_BaxABaxM_to_BaxA_BaxA_kc': 1.1711099807780889,
#  'catalyze_BidMBakM_to_BidM_BakA_kc': 1.3866441076133829,
#  'catalyze_BidMBaxC_to_BidM_BaxM_kc': 1.5297652147217957,
#  'catalyze_BidMBaxM_to_BidM_BaxA_kc': 1.6841807207258095,
#  'catalyze_C3AC6pro_to_C3A_C6A_kc': 1.264264984146513,
#  'catalyze_C3APARPU_to_C3A_PARPC_kc': 1.4161949157934539,
#  'catalyze_C6AC8pro_to_C6A_C8A_kc': 1.420878009465659,
#  'catalyze_C8ABidU_to_C8A_BidT_kc': 1.1773592014779495,
#  'catalyze_C8AC3pro_to_C8A_C3A_kc': 1.2309827187528222,
#  'catalyze_CytoCAApafI_to_CytoCA_ApafA_kc': 1.0799498388681863,
#  'catalyze_DISCC8pro_to_DISC_C8A_kc': 1.3084266201969614,
#  'catalyze_XIAPC3A_to_XIAP_C3ub_kc': 1.0993061811910902,
#  'convert_ApafA_C9_to_Apop_kf': 1.3067753622179008,
#  'convert_ApafA_C9_to_Apop_kr': 1.3930099949599077,
#  'convert_LR_to_DISC_kc': 1.5165743505796341,
#  'equilibrate_BidT_to_BidM_kf': 1.0497448796046023,
#  'equilibrate_BidT_to_BidM_kr': 1.2834124104530977,
#  'equilibrate_CytoCC_to_CytoCA_kf': 1.3821349873364637,
#  'equilibrate_CytoCC_to_CytoCA_kr': 1.2099713110329415,
#  'equilibrate_SmacC_to_SmacA_kf': 1.4694429820944375,
#  'equilibrate_SmacC_to_SmacA_kr': 1.217812219178553,
#  'pore_transport_complex_BakA_4_CytoCM_kf': 1.2197317643665515,
#  'pore_transport_complex_BakA_4_CytoCM_kr': 1.3160026569481627,
#  'pore_transport_complex_BakA_4_SmacM_kf': 1.4194456759201655,
#  'pore_transport_complex_BakA_4_SmacM_kr': 1.3156414418570286,
#  'pore_transport_complex_BaxA_4_CytoCM_kf': 1.9074287128362637,
#  'pore_transport_complex_BaxA_4_CytoCM_kr': 1.3004210928223996,
#  'pore_transport_complex_BaxA_4_SmacM_kf': 1.3672288334600402,
#  'pore_transport_complex_BaxA_4_SmacM_kr': 1.6703491854519841,
#  'pore_transport_dissociate_BakA_4_CytoCC_kc': 1.8303496674211193,
#  'pore_transport_dissociate_BakA_4_SmacC_kc': 1.5936290747307271,
#  'pore_transport_dissociate_BaxA_4_CytoCC_kc': 1.4726396810200399,
#  'pore_transport_dissociate_BaxA_4_SmacC_kc': 1.3330017487789414}

# %%
sample_plots(param_trace)
# Out:
# 20000
# 5
# 20000
# [<matplotlib.figure.Figure at 0x107180e50>,
#  <matplotlib.figure.Figure at 0x10d6c3e10>,
#  <matplotlib.figure.Figure at 0x10e704cd0>,
#  <matplotlib.figure.Figure at 0x10f5f0750>,
#  <matplotlib.figure.Figure at 0x112d497d0>,
#  <matplotlib.figure.Figure at 0x1139272d0>,
#  <matplotlib.figure.Figure at 0x1172e16d0>,
#  <matplotlib.figure.Figure at 0x117ce5550>,
#  <matplotlib.figure.Figure at 0x119515510>,
#  <matplotlib.figure.Figure at 0x119f854d0>,
#  <matplotlib.figure.Figure at 0x11b0e9650>,
#  <matplotlib.figure.Figure at 0x11d2667d0>,
#  <matplotlib.figure.Figure at 0x11e3b74d0>,
#  <matplotlib.figure.Figure at 0x11f51c110>,
#  <matplotlib.figure.Figure at 0x12168a390>,
#  <matplotlib.figure.Figure at 0x1227ef750>,
#  <matplotlib.figure.Figure at 0x12395c410>]

# %%
trace_arr = create_trace_matrix(param_trace, burnin=10000)

# %%
plot_histograms(param_trace, trace_arr, plot_original_vals=True, model=model, title_fontsize=10)
# Out:
# [<matplotlib.figure.Figure at 0x12a4a5dd0>,
#  <matplotlib.figure.Figure at 0x126e92250>,
#  <matplotlib.figure.Figure at 0x1070ebdd0>,
#  <matplotlib.figure.Figure at 0x12711d590>,
#  <matplotlib.figure.Figure at 0x11011bc10>,
#  <matplotlib.figure.Figure at 0x1104340d0>,
#  <matplotlib.figure.Figure at 0x1107495d0>,
#  <matplotlib.figure.Figure at 0x110a58d50>,
#  <matplotlib.figure.Figure at 0x110d59b10>,
#  <matplotlib.figure.Figure at 0x115158a50>,
#  <matplotlib.figure.Figure at 0x115476090>,
#  <matplotlib.figure.Figure at 0x11578f6d0>,
#  <matplotlib.figure.Figure at 0x115ac9090>,
#  <matplotlib.figure.Figure at 0x115de0290>,
#  <matplotlib.figure.Figure at 0x1160f27d0>,
#  <matplotlib.figure.Figure at 0x1275caed0>,
#  <matplotlib.figure.Figure at 0x129c5c7d0>]
