# %%
import pickle
from helper_fxns import convert_param_vec_dict_to_param_dict, gelman_rubin_trace_dict, print_convergence_summary, sample_plots, create_trace_matrix, plot_histograms
from earm.lopez_embedded import model
# %matplotlib inline
# Out:
# Warning: statsmodels and/or patsy not found, not importing glm submodule.
# /Library/Python/2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# /Library/Python/2.7/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
trace = pickle.load(open('/Users/Erin/git/moo_and_mcmc/pymc/earm_mtdreamzs_5chain_nopsohist_nobounds.p'))

# %%
trace_momp = trace['momp']
trace_ecrp = trace['ecrp']
trace_icrp = trace['icrp']

# %%
del trace['momp']
del trace['ecrp']
del trace['icrp']

# %%
param_trace = convert_param_vec_dict_to_param_dict(trace, model.parameters_rules())

# %%
del param_trace['param_list']

# %%
print_convergence_summary(param_trace)
# Out:
# Number of parameters with GR below 1.2:  72  of  105  parameters.
# Percent of parameters with GR below 1.2:  68.5714285714
# Number of parameters with GR below 1.1:  42  of  105  parameters.
# Percent of parameters with GR below 1.1:  40.0
# [72, 68.57142857142857, 42, 40.0]

# %%
sample_plots(param_trace)
# Out:
# 20000
# 5
# 20000
# [<matplotlib.figure.Figure at 0x1148fdd10>,
#  <matplotlib.figure.Figure at 0x114e1ee50>,
#  <matplotlib.figure.Figure at 0x115e87d10>,
#  <matplotlib.figure.Figure at 0x116d74790>,
#  <matplotlib.figure.Figure at 0x11a545810>,
#  <matplotlib.figure.Figure at 0x11f1e42d0>,
#  <matplotlib.figure.Figure at 0x121a66710>,
#  <matplotlib.figure.Figure at 0x1224e0590>,
#  <matplotlib.figure.Figure at 0x123c99550>,
#  <matplotlib.figure.Figure at 0x124781510>,
#  <matplotlib.figure.Figure at 0x1258e4690>,
#  <matplotlib.figure.Figure at 0x126a4a810>,
#  <matplotlib.figure.Figure at 0x127b9a4d0>,
#  <matplotlib.figure.Figure at 0x128cff150>,
#  <matplotlib.figure.Figure at 0x129e63390>,
#  <matplotlib.figure.Figure at 0x12afc8790>,
#  <matplotlib.figure.Figure at 0x12c136450>]

# %%
trace_arr = create_trace_matrix(param_trace, burnin=10000)

# %%
plot_histograms(param_trace, trace_arr, plot_original_vals=True, model=model, title_fontsize=10)
# Out:
# [<matplotlib.figure.Figure at 0x131c4e790>,
#  <matplotlib.figure.Figure at 0x12e647250>,
#  <matplotlib.figure.Figure at 0x10ddcb410>,
#  <matplotlib.figure.Figure at 0x12e8d0290>,
#  <matplotlib.figure.Figure at 0x117844910>,
#  <matplotlib.figure.Figure at 0x117b52c90>,
#  <matplotlib.figure.Figure at 0x117e772d0>,
#  <matplotlib.figure.Figure at 0x118186a50>,
#  <matplotlib.figure.Figure at 0x118485810>,
#  <matplotlib.figure.Figure at 0x11c8b0750>,
#  <matplotlib.figure.Figure at 0x11cbc0c90>,
#  <matplotlib.figure.Figure at 0x11cee63d0>,
#  <matplotlib.figure.Figure at 0x11d211c90>,
#  <matplotlib.figure.Figure at 0x11d53a050>,
#  <matplotlib.figure.Figure at 0x11d8484d0>,
#  <matplotlib.figure.Figure at 0x12ed7fbd0>,
#  <matplotlib.figure.Figure at 0x1314104d0>]
