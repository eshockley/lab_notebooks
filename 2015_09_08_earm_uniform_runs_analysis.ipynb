# %%
import pickle
# %matplotlib inline
from helper_fxns import convert_param_vec_dict_to_param_dict, gelman_rubin_trace_dict, create_trace_matrix, sample_plots, plot_histograms
import numpy as np
import os
from earm.lopez_embedded import model

# %%
os.chdir('/Users/Erin/git/moo_and_mcmc/pymc')

# %%
earm_mtdreamzs_5chain_a = pickle.load(open('earm_mtdreamzs_5chain_a.p'))

# %%
earm_mtdreamzs_5chain_a_icrp = earm_mtdreamzs_5chain_a['icrp']
earm_mtdreamzs_5chain_a_ecrp = earm_mtdreamzs_5chain_a['ecrp']
earm_mtdreamzs_5chain_a_momp = earm_mtdreamzs_5chain_a['momp']

# %%
del earm_mtdreamzs_5chain_a['icrp']
del earm_mtdreamzs_5chain_a['ecrp']
del earm_mtdreamzs_5chain_a['momp']

# %%
earm_mtdreamzs_5chain_a_paramtrace = convert_param_vec_dict_to_param_dict(earm_mtdreamzs_5chain_a, model.parameters_rules())

# %%
sample_plots(earm_mtdreamzs_5chain_a_paramtrace)
# Out:
# 60000
# 5
# 60000
# ...

# %%
# Out:
# [array([-5.22193817, -5.22193817, -5.2220835 , ..., -5.22205949,
#         -5.22194817, -5.22239413]),
#  array([-5.22211235, -5.22211235, -5.22216175, ..., -5.22223832,
#         -5.22215479, -5.22215479]),
#  array([-5.22185827, -5.22204001, -5.22277776, ..., -5.22187091,
#         -5.22187091, -5.22187091]),
#  array([-5.22350733, -5.22350733, -5.22268695, ..., -5.22246526,
#         -5.22246526, -5.22217228]),
#  array([-5.22212509, -5.22212509, -5.2218523 , ..., -5.22205582,
#         -5.22205582, -5.22279427])]
