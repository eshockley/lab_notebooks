# %%
import numpy as np
import os
from earm.lopez_embedded import model as earm
from emcee.autocorr import integrated_time
from helper_fxns import gelman_rubin_trace_dict, convert_param_vec_dict_to_param_dict, print_convergence_summary, sample_plots
import pickle
# %matplotlib inline
# Out:
# ...
# /Library/Python/2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# /Library/Python/2.7/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
os.chdir('/Users/Erin/git/moo_and_mcmc/emcee/')

# %%
emcee_data = np.load('earm_uniform_emcee_500_3000.npy')

# %%
emcee_data.shape
# Out:
# (500, 3000, 105)

# %%
emcee_data
# Out:
# array([[[-6.39788895,  3.39800051, -5.00017212, ..., -4.54400497,
#           1.54414588,  1.0000912 ],
#         [-6.39784974,  3.39796699, -5.00024064, ..., -4.54396108,
#           1.54418915,  1.0001764 ],
#         [-6.39783518,  3.39800771, -5.00026585, ..., -4.54392544,
#           1.54422702,  1.00020861],
#         ...,
#         [-6.70798637,  3.88410271, -5.37001363, ..., -3.79143831,
#           1.57235639, -0.58834854],
#         [-6.70798637,  3.88410271, -5.37001363, ..., -3.79143831,
#           1.57235639, -0.58834854],
#         [-6.70798637,  3.88410271, -5.37001363, ..., -3.79143831,
#           1.57235639, -0.58834854]],
#
#        [[-6.39779079,  3.39802091, -4.99995639, ..., -4.54412381,
#           1.54397944,  1.00014472],
#         [-6.39771867,  3.39817171, -5.00002847, ..., -4.54420122,
#           1.5439575 ,  1.00025213],
#         [-6.39769725,  3.39821373, -5.0000051 , ..., -4.54422468,
#           1.54391876,  1.00030634],
#         ...,
# ...

# %%
acor = integrated_time(np.mean(emcee_data, axis=0), axis=0)

# %%
trace = {}
trace['params'] = [emcee_data[n] for n in range(len(emcee_data))]

# %%
trace
# Out:
# {'params': [array([[-6.39788895,  3.39800051, -5.00017212, ..., -4.54400497,
#            1.54414588,  1.0000912 ],
#          [-6.39784974,  3.39796699, -5.00024064, ..., -4.54396108,
#            1.54418915,  1.0001764 ],
#          [-6.39783518,  3.39800771, -5.00026585, ..., -4.54392544,
#            1.54422702,  1.00020861],
#          ...,
#          [-6.70798637,  3.88410271, -5.37001363, ..., -3.79143831,
#            1.57235639, -0.58834854],
#          [-6.70798637,  3.88410271, -5.37001363, ..., -3.79143831,
#            1.57235639, -0.58834854],
#          [-6.70798637,  3.88410271, -5.37001363, ..., -3.79143831,
#            1.57235639, -0.58834854]]),
#   array([[-6.39779079,  3.39802091, -4.99995639, ..., -4.54412381,
#            1.54397944,  1.00014472],
#          [-6.39771867,  3.39817171, -5.00002847, ..., -4.54420122,
#            1.5439575 ,  1.00025213],
#          [-6.39769725,  3.39821373, -5.0000051 , ..., -4.54422468,
#            1.54391876,  1.00030634],
# ...

# %%
param_dict = convert_param_vec_dict_to_param_dict(trace, earm.parameters_rules())

# %%
del param_dict['param_list']

# %%
gelman_rubin_trace_dict(param_dict)
# Out:
# var:  catalyze_ApopC3pro_to_Apop_C3A_kc
# between chain variance:  457.234213561
# within chain variance:  0.016449488701
# marginal posterior variance estimate:  0.321261331416
# var:  bind_C3A_C6pro_to_C3AC6pro_kf
# between chain variance:  201.928228709
# within chain variance:  0.0110205819097
# marginal posterior variance estimate:  0.145632053995
# var:  pore_transport_complex_BakA_4_SmacM_kr
# between chain variance:  546.993898774
# within chain variance:  0.0125055857024
# marginal posterior variance estimate:  0.377159847828
# var:  bind_C3A_C6pro_to_C3AC6pro_kr
# between chain variance:  436.689032482
# within chain variance:  0.0160624926577
# marginal posterior variance estimate:  0.307177805984
# var:  catalyze_C8AC3pro_to_C8A_C3A_kc
# between chain variance:  427.393103314
# within chain variance:  0.0109627954043
# marginal posterior variance estimate:  0.295884222416
# var:  pore_transport_complex_BakA_4_SmacM_kf
# between chain variance:  302.653413266
# ...

# %%
sample_plots(param_dict)
# Out:
# 3000
# 500
# 3000
# ...
